# %% [markdown]
# # Introduzione
#
# Questa lezione sarà una dimostrazione di alcuni strumenti e librerie python, usati diffusamente in ambito di ricerca, data science, ecc...
#
# In particolare vedremo
# - la shell IPython
# - l'ambiente di lavoro Jupyter
# - piccoli accenni a Markdown
# - la libreria `numpy`
# - la librerie per fare grafici `matplotlib`
#
# La dimostrazione di questi strumenti non potrà essere esaustiva. L'importante è capire a cosa servono, saper usarli in maniera basilare, e trovare la documentazione utile per approfondire.
#
# ## Risorse utili
#
# Navigando nelle pagine di questi progetti troverete documentazione, **tutorial** e molti più dettagli di quelli che vi potrebbero servire.
#
# - [IPython](https://ipython.org/)
# - [Jupyter](https://jupyter.org/)
# - [Numpy](https://numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Markdown](https://www.markdownguide.org/basic-syntax)

# %% [markdown]
# ## Installazione
#
# Se avete un'installazione di Python funzionante, per installare questi strumenti nel vostro sistema basterà lanciare il seguente comando da terminale
#
# ```bash
# $ pip install ipython jupyter numpy matplotlib
# ```
#
# oppure, se questo non funziona,
#
# ```bash
# $ python -m pip install ipython jupyter numpy matplotlib
# ```
#
# Se utilizzate degli ambienti python con una propria gestione dei pacchetti (come Anaconda oppure Thonny) dovrete usare il metodo di installazione appropriato.

# %% [markdown]
# ## Esempio 1: una matrice casuale

# %%
import numpy as np
import matplotlib.pyplot as plt
A = np.random.randn(10,15)
print(A[0])
plt.matshow(A)
# Out:
# [-1.93528399  0.879741   -0.36957058 -0.06416762 -0.54380214  0.22170745
#   0.84227849  0.9173608  -0.96744667  0.45114806 -0.06490167  0.3033539
#  -1.25001796 -3.02568968 -1.73853453]

# %% [markdown]
# ## Esempio 2: altra dimensione e colore del plot

# %%
B = np.random.randn(10,40)
print(B[0])
plt.matshow(B,cmap=plt.cm.inferno)
# Out:
# [-2.00424136 -0.80634976 -0.73684024  0.97154457 -2.47314879  0.04053072
#   1.00493182 -0.98294971  2.40535541  1.82498282  1.49769915 -0.9619444
#  -0.58360577 -1.50456964  0.22260153 -0.81909099  0.72305491 -0.43263346
#   0.2654242   1.39535789 -1.9501386  -1.52060377  0.08582163 -1.29949609
#  -0.35836583  0.96453943 -1.30453706 -0.01561131  0.38181645  0.19746232
#   1.39941233  1.68599536  0.50022771  0.10732824  0.59241507  1.15132271
#   1.36248705 -0.55213172 -0.85612009 -0.07630558]

# %% [markdown]
# ## Esempio 3: grafico di una funzione matematica

# %%
X = np.linspace(-2*np.pi,2*np.pi,1000)
Y1 = np.sin(X)
Y2 = np.sin(2*X)
plt.figure(figsize=(20,5))
plt.plot(X,Y1,X,Y2)

# %% [markdown]
# ## Esempio 4: modifichiamo la frequenza

# %%
from ipywidgets import interact, IntSlider

def graph(n):
    X = np.linspace(-2*np.pi,2*np.pi,1000)
    Y1 = np.sin(X)
    Y2 = np.sin(n*X)
    plt.figure(figsize=(20,5))
    return plt.plot(X,Y1,X,Y2)

interact(graph,n=IntSlider(min=1,max=10,step=1))
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=10, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.graph(n)>

# %% [markdown]
# # Indice degli argomenti

# %% [markdown]
# - [Introduzione](./start.ipynb) il foglio di lavoro che state leggendo adesso
# - [IPython](./ipython.ipynb) veloce introduzione alla shell `IPython`
# - [Un esercizio di confronto di performance](./more.ipynb) facciamo pratica con `IPython` e `Jupyter`
# - [Numpy: array multidimensionali efficienti](./numpy.ipynb) primi passi con la libreria `numpy`
# - [Divertiamoci un po' con numpy](./playing.ipynb) facciamo pratica con `numpy`
# - [Regressione lineare attraverso la discesa del gradiente](./gradient.ipynb) un esercizio di ottimizzazione
# - [Funzioni per creare array](./create.ipynb) approfondiamo `numpy`: creazione di array
# - [Operazioni algebriche](./algebra.ipynb) approfondiamo `numpy`: operazioni algebriche tra array
# - [Indicizzazione](./indexing.ipynb) approfondiamo `numpy`: selezione di elementi nell'array
